# %% [markdown]
# # Amer Nour Eddin | 213171245 | Homework 2

# %% [markdown]
# Read NSFG respondent data with .ReadFemResp() function that provided by nsfg.py and assign it a variable that called pres (This is not a question)
#
# - Select the fmar1age column that the age of respondents' at first mariage from pres,find frequencies for each age and print the values with sorted by age (tip: with value_counts() function may help) then Make a histogram of fmar1age the age of respondents' at first mariage. To interpret the codes see the This website
#  (2 pt)
#
#
# - Find the respondents' number of mariage by fmarno and find frequencies for each number of mariage and print the values with sorted by number of mariage (tip: with value_counts() function may help) then Make a histogram of fmarno the number of mariage that done by respondents. To interpret the codes see the This website
#  (2 pt)
#
#
# - Find the total income for the respondent's family by totincr and find frequencies for each number of mariage and print the values with sorted by number of mariage (tip: with value_counts() function may help) then Make a histogram of totincr the number of mariage that done by respondents. To interpret the codes see the This website
#  (2 pt)
#
#
# - Separate the respondents two group by number of mariage(use fmarno column) and assign them to variables that called neverMarried and married. If respondent's number of mariage is 0 assign them into neverMarried variable, If respondent's number of mariage is 1 and higher than 1 assign them into married variable. Create a histogram that shows the total income for the respondent's family(use totincr column) that contain these two variables in one histogram but show them with different bar(column, bin) for each group by income category these two variables must be next-by-next. (3 pt)
#
#
# - Find the minumum, maximum, standard deviation, variance and mean of neverMarried and married respondents' total income and print them in a sentence for each variable. (3 pt)
#
#
#  -Note that: There are 5 question and total of points is 12 but maximum points that can be get 10 points. Do not forget the give the name to your histogram labels(histogram's label, x-axis and y-axis label), and width of the histograms' columns must be 0.5. In addition, Your answers/codes must be uploaded to your github accounts inside a folder that called Homework2_{YourStudentNumber} then after you upload your code notify me with email that contains your github account link. The due date is the end of the next Wednesday(15.03.2017).

# %%
from __future__ import print_function, division
# %matplotlib inline
import numpy as np
import nsfg
import first
import thinkstats2
import thinkplot

# %%
pres = nsfg.ReadFemResp()
pres
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0       2298        1         5         5            1          5.0     27
# 1       5012        1         5         1            5          5.0     42
# 2      11586        1         5         1            5          5.0     43
# 3       6794        5         5         4            1          5.0     15
# 4        616        1         5         4            1          5.0     20
# 5        845        1         5         4            1          5.0     42
# 6      10333        5         5         3            1          5.0     17
# 7        855        5         5         4            5          5.0     22
# 8       8656        5         5         4            1          5.0     38
# 9       3566        5         5         4            5          5.0     21
# 10      5917        1         5         3            1          5.0     44
# ...

# %%
x1 = pres.fmar1age.value_counts().sort_index() # age of respondents at first mariage + frequencies for each age and the values with sorted by age
x1
# Out:
# 9.0       1
# 11.0      2
# 12.0      1
# 13.0      3
# 14.0     18
# 15.0     50
# 16.0    115
# 17.0    173
# 18.0    342
# 19.0    328
# 20.0    353
# 21.0    364
# 22.0    381
# 23.0    359
# 24.0    285
# 25.0    261
# 26.0    233
# 27.0    177
# 28.0    150
# 29.0    129
# 30.0     97
# 31.0     72
# 32.0     52
# 33.0     49
# 34.0     29
# 35.0     35
# 36.0     14
# 37.0     14
# 38.0     10
# 39.0     10
# 40.0      7
# 41.0      6
# 42.0      3
# 43.0      3
# Name: fmar1age, dtype: int64

# %%
hist = thinkstats2.Hist(pres.fmar1age, label='First Marriage age')
thinkplot.Hist(hist, width = 0.45)
thinkplot.Config(xlabel='Age at first marriage', ylabel='Count')

# %%
x2 = pres.fmarno.value_counts().sort_index() # number of mariage and frequencies for each number of mariage sorted by number of mariage
x2
# Out:
# 0    3517
# 1    3436
# 2     582
# 3      90
# 4      15
# 5       3
# Name: fmarno, dtype: int64

# %%
hist = thinkstats2.Hist(pres.fmarno, label='Number of times being married')
thinkplot.Hist(hist, width = 0.30)
thinkplot.Config(xlabel='Number of times', ylabel='Count')

# %%
x3 = pres.totincr.value_counts().sort_index()
x3
# Out:
# 1      299
# 2      301
# 3      266
# 4      421
# 5      445
# 6      559
# 7      583
# 8      606
# 9      607
# 10     468
# 11     647
# 12     658
# 13     623
# 14    1160
# Name: totincr, dtype: int64

# %%
hist = thinkstats2.Hist(pres.totincr, label='Total income of Rs family')    
thinkplot.Hist(hist, width=0.50)
thinkplot.Config(xlabel='Income Category', ylabel='Count')

# Income Catagories

# value 	   label	        	Total
# 1 	      UNDER $5000	        	299
# 2 	      $5000-$7499	        	301
# 3 	      $7500-$9999	        	266
# 4 	      $10,000-$12,499	    	421
# 5 	      $12,500-$14,999	    	445
# 6 	      $15,000-$19,999	    	559
# 7 	      $20,000-$24,999	    	583
# 8 	      $25,000-$29,999	    	606
# 9 	      $30,000-$34,999	    	607
# 10	      $35,000-$39,999	    	468
# 11	      $40,000-$49,999	    	647
# 12	      $50,000-$59,000	    	658
# 13	      $60,000-$74,999	    	623
# 14	      $75,000 OR MORE	    	1160
#         	Total	                	7643

# %%
neverMarried = pres[pres.fmarno==0] #respondents that their number of mariage is 0 
married = pres[pres.fmarno>=1] #respondents that their number of mariage is 1 or more 

neverMarried_hist = thinkstats2.Hist(neverMarried.totincr, label='Never Married')
married_hist = thinkstats2.Hist(married.totincr, label='Married')

thinkplot.PrePlot(2)
thinkplot.Hist(neverMarried_hist, align='right', width=0.35)
thinkplot.Hist(married_hist, align='left', width=width)
thinkplot.Config(xlabel='Total income', ylabel='Count')

# %%
y0 = neverMarried.totincr
y1 = married.totincr

# %%
neverMarried_Min = y0.min()
neverMarried_Max = y0.max()
neverMarried_stdDevi = y0.std()
neverMarried_variance = y0.var()
neverMarried_mean = y0.mean()

print("The Minimum Value of total income for respondents who are Never married is %d." %neverMarried_Min)
print("The Maximum Value of total income for respondents who are Never married is %d." %neverMarried_Max)
print("The Standard Deviation Value of total income for respondents who are Never married is %f." %neverMarried_stdDevi)
print("The Variance Value of total income for respondents who are Never married is %f." %neverMarried_variance)
print("The Mean Value of total income for respondents who are Never married is %f." %neverMarried_mean)
# Out:
# The Minimum Value of total income for respondents who are Never married is 1.
# The Maximum Value of total income for respondents who are Never married is 14.
# The Standard Deviation Value of total income for respondents who are Never married is 3.980809.
# The Variance Value of total income for respondents who are Never married is 15.846839.
# The Mean Value of total income for respondents who are Never married is 8.020756.

# %%
Married_Min = y1.min()
Married_Max = y1.max()
Married_stdDevi = y1.std()
Married_variance = y1.var()
Married_mean = y1.mean()

print("The Minimum Value of total income for respondents who are married is %d." %Married_Min)
print("The Maximum Value of total income for respondents who are married is %d." %Married_Max)
print("The Standard Deviation Value of total income for respondents who are married is %f." %Married_stdDevi)
print("The Variance Value of total income for respondents who are married is %f." %Married_variance)
print("The Mean Value of total income for respondents who are married is %f." %Married_mean)
# Out:
# The Minimum Value of total income for respondents who are married is 1.
# The Maximum Value of total income for respondents who are married is 14.
# The Standard Deviation Value of total income for respondents who are married is 3.714652.
# The Variance Value of total income for respondents who are married is 13.798643.
# The Mean Value of total income for respondents who are married is 9.495153.
